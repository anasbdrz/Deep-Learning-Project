# %%
import os
import random
import itertools
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from tqdm import tqdm
import torchvision


import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as T
from torchvision.utils import save_image
from torchvision import transforms

# %%
class ResidualBlock(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.block = nn.Sequential(
            nn.ReflectionPad2d(1),
            nn.Conv2d(channels, channels, kernel_size=3),
            nn.InstanceNorm2d(channels),
            nn.ReLU(inplace=True),
            nn.ReflectionPad2d(1),
            nn.Conv2d(channels, channels, kernel_size=3),
            nn.InstanceNorm2d(channels),
        )
        
    def forward(self, x):
        return x + self.block(x)

# %%
class Generator(nn.Module):
    def __init__(self, in_channels=3, out_channels=3, n_residual_blocks=9):
        super().__init__()

        model = [
            nn.ReflectionPad2d(3),
            nn.Conv2d(in_channels, 64, kernel_size=7),
            nn.InstanceNorm2d(64),
            nn.ReLU(inplace=True)
        ]

        # Downsampling
        in_features = 64
        out_features = in_features * 2
        for _ in range(2):
            model += [
                nn.Conv2d(in_features, out_features, kernel_size=3, stride=2, padding=1),
                nn.InstanceNorm2d(out_features),
                nn.ReLU(inplace=True),
            ]
            in_features = out_features
            out_features *= 2

        # Residual blocks
        for _ in range(n_residual_blocks):
            model += [ResidualBlock(in_features)]

        # Upsampling
        out_features = in_features // 2
        for _ in range(2):
            model += [
                nn.ConvTranspose2d(in_features, out_features, kernel_size=3, stride=2, padding=1, output_padding=1),
                nn.InstanceNorm2d(out_features),
                nn.ReLU(inplace=True),
            ]
            in_features = out_features
            out_features //= 2

        model += [
            nn.ReflectionPad2d(3),
            nn.Conv2d(64, out_channels, kernel_size=7),
            nn.Tanh()
        ]

        self.model = nn.Sequential(*model)

    def forward(self, x):
        return self.model(x)

# %%
# Assuming you have a Generator class defined
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the pre-trained generator model
G_AB = Generator().to(device)
G_AB.load_state_dict(torch.load("G_BA_monet.pth", map_location=device))
G_AB.eval()  # Set model to evaluation mode

transform = T.Compose([
    T.Resize(256),
    T.ToTensor(),
    T.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# %%
input_folder = "datasets/real_imagesv2/photo_jpg"
output_folder = "outputs/monet_stylev2"
os.makedirs(output_folder, exist_ok=True)

# %%
for filename in os.listdir(input_folder):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
        img_path = os.path.join(input_folder, filename)
        img = Image.open(img_path).convert('RGB')
        img_tensor = transform(img).unsqueeze(0).to(device)

        with torch.no_grad():
            fake_img = G_AB(img_tensor)

        # Denormalize for saving
        fake_img = 0.5 * (fake_img + 1.0)
        save_path = os.path.join(output_folder, filename)
        save_image(fake_img, save_path)
        print(f"Saved stylized image to: {save_path}")
# Out:
# Saved stylized image to: outputs/monet_stylev2\00068bc07f.jpg
# Saved stylized image to: outputs/monet_stylev2\000910d219.jpg
# Saved stylized image to: outputs/monet_stylev2\000ded5c41.jpg
# Saved stylized image to: outputs/monet_stylev2\00104fd531.jpg
# Saved stylized image to: outputs/monet_stylev2\001158d595.jpg
# Saved stylized image to: outputs/monet_stylev2\0033c5f971.jpg
# Saved stylized image to: outputs/monet_stylev2\0039ebb598.jpg
# Saved stylized image to: outputs/monet_stylev2\003aab6fdd.jpg
# Saved stylized image to: outputs/monet_stylev2\003c6c30e0.jpg
# Saved stylized image to: outputs/monet_stylev2\00479e2a21.jpg
# Saved stylized image to: outputs/monet_stylev2\005f987f56.jpg
# Saved stylized image to: outputs/monet_stylev2\0080f94ebc.jpg
# Saved stylized image to: outputs/monet_stylev2\00882b7e1d.jpg
# Saved stylized image to: outputs/monet_stylev2\009d534136.jpg
# Saved stylized image to: outputs/monet_stylev2\009ddaed1f.jpg
# Saved stylized image to: outputs/monet_stylev2\00aeb60e25.jpg
# Saved stylized image to: outputs/monet_stylev2\00c6a0ad1e.jpg
# Saved stylized image to: outputs/monet_stylev2\00dcf0f1e3.jpg
# Saved stylized image to: outputs/monet_stylev2\00dff09ebe.jpg
# Saved stylized image to: outputs/monet_stylev2\00e1798585.jpg
# Saved stylized image to: outputs/monet_stylev2\00e64e1b2c.jpg
# Saved stylized image to: outputs/monet_stylev2\00f78547f0.jpg
# Saved stylized image to: outputs/monet_stylev2\00fcff630e.jpg
# Saved stylized image to: outputs/monet_stylev2\01135e4771.jpg
# Saved stylized image to: outputs/monet_stylev2\011f46de73.jpg
# Saved stylized image to: outputs/monet_stylev2\012df5ce29.jpg
# Saved stylized image to: outputs/monet_stylev2\01416e7ada.jpg
# Saved stylized image to: outputs/monet_stylev2\01480da48f.jpg
# Saved stylized image to: outputs/monet_stylev2\0159685c51.jpg
# Saved stylized image to: outputs/monet_stylev2\015f79b672.jpg
# Saved stylized image to: outputs/monet_stylev2\01622039ef.jpg
# Saved stylized image to: outputs/monet_stylev2\0162322d2d.jpg
# Saved stylized image to: outputs/monet_stylev2\016d408833.jpg
# Saved stylized image to: outputs/monet_stylev2\016f524878.jpg
# Saved stylized image to: outputs/monet_stylev2\017018f377.jpg
# Saved stylized image to: outputs/monet_stylev2\01771d99c3.jpg
# Saved stylized image to: outputs/monet_stylev2\017aacad6e.jpg
# Saved stylized image to: outputs/monet_stylev2\018be60883.jpg
# Saved stylized image to: outputs/monet_stylev2\018db0f253.jpg
# Saved stylized image to: outputs/monet_stylev2\01952c7673.jpg
# Saved stylized image to: outputs/monet_stylev2\01971e48e5.jpg
# Saved stylized image to: outputs/monet_stylev2\019cf7682d.jpg
# Saved stylized image to: outputs/monet_stylev2\01ae8be57e.jpg
# Saved stylized image to: outputs/monet_stylev2\01af5f8623.jpg
# Saved stylized image to: outputs/monet_stylev2\01bce47d3f.jpg
# Saved stylized image to: outputs/monet_stylev2\01c4f86e3e.jpg
# Saved stylized image to: outputs/monet_stylev2\01f7a6398e.jpg
# Saved stylized image to: outputs/monet_stylev2\02001e59af.jpg
# Saved stylized image to: outputs/monet_stylev2\0212257854.jpg
# Saved stylized image to: outputs/monet_stylev2\021df2c226.jpg
# Saved stylized image to: outputs/monet_stylev2\022ca16b0f.jpg
# Saved stylized image to: outputs/monet_stylev2\023637f8fb.jpg
# Saved stylized image to: outputs/monet_stylev2\023eed0385.jpg
# Saved stylized image to: outputs/monet_stylev2\023f3cbb75.jpg
# Saved stylized image to: outputs/monet_stylev2\0240a597f5.jpg
# Saved stylized image to: outputs/monet_stylev2\024d98032b.jpg
# Saved stylized image to: outputs/monet_stylev2\0254fc91bd.jpg
# Saved stylized image to: outputs/monet_stylev2\02620a36f7.jpg
# Saved stylized image to: outputs/monet_stylev2\026ac33f9c.jpg
# Saved stylized image to: outputs/monet_stylev2\029524fd91.jpg
# Saved stylized image to: outputs/monet_stylev2\029854a790.jpg
# Saved stylized image to: outputs/monet_stylev2\02a1366c74.jpg
# Saved stylized image to: outputs/monet_stylev2\02a4445906.jpg
# Saved stylized image to: outputs/monet_stylev2\02b232fc78.jpg
# Saved stylized image to: outputs/monet_stylev2\02c43186c8.jpg
# Saved stylized image to: outputs/monet_stylev2\02c6c1f6a9.jpg
# Saved stylized image to: outputs/monet_stylev2\02cd89f56d.jpg
# Saved stylized image to: outputs/monet_stylev2\02d763f1c2.jpg
# Saved stylized image to: outputs/monet_stylev2\02ded12bbd.jpg
# Saved stylized image to: outputs/monet_stylev2\02ea18a456.jpg
# Saved stylized image to: outputs/monet_stylev2\02ec33e094.jpg
# Saved stylized image to: outputs/monet_stylev2\0312af1e14.jpg
# Saved stylized image to: outputs/monet_stylev2\032389e868.jpg
# Saved stylized image to: outputs/monet_stylev2\03242238ae.jpg
# Saved stylized image to: outputs/monet_stylev2\0324f82fee.jpg
# Saved stylized image to: outputs/monet_stylev2\0341fa51d0.jpg
# Saved stylized image to: outputs/monet_stylev2\0344a47135.jpg
# Saved stylized image to: outputs/monet_stylev2\034627340c.jpg
# Saved stylized image to: outputs/monet_stylev2\0362dd81bb.jpg
# Saved stylized image to: outputs/monet_stylev2\0378bcc7c9.jpg
# Saved stylized image to: outputs/monet_stylev2\03950208ff.jpg
# Saved stylized image to: outputs/monet_stylev2\03a17d96e1.jpg
# Saved stylized image to: outputs/monet_stylev2\03a21c1b9c.jpg
# Saved stylized image to: outputs/monet_stylev2\03a2b7ce83.jpg
# Saved stylized image to: outputs/monet_stylev2\03ae080a47.jpg
# Saved stylized image to: outputs/monet_stylev2\03ae26ed88.jpg
# Saved stylized image to: outputs/monet_stylev2\03bac83f64.jpg
# Saved stylized image to: outputs/monet_stylev2\03be88270f.jpg
# Saved stylized image to: outputs/monet_stylev2\03c5d1d098.jpg
# Saved stylized image to: outputs/monet_stylev2\03c9f2e3c2.jpg
# Saved stylized image to: outputs/monet_stylev2\03c9f3d584.jpg
# Saved stylized image to: outputs/monet_stylev2\03cc206144.jpg
# Saved stylized image to: outputs/monet_stylev2\03d47c18a5.jpg
# Saved stylized image to: outputs/monet_stylev2\03d6a4d860.jpg
# Saved stylized image to: outputs/monet_stylev2\03dde7a28f.jpg
# Saved stylized image to: outputs/monet_stylev2\03e48faafa.jpg
# Saved stylized image to: outputs/monet_stylev2\03fd7067c1.jpg
# Saved stylized image to: outputs/monet_stylev2\03fe5d2263.jpg
# Saved stylized image to: outputs/monet_stylev2\0409e76de0.jpg
# Saved stylized image to: outputs/monet_stylev2\0425fc7ce5.jpg
# Saved stylized image to: outputs/monet_stylev2\042f0e804d.jpg
# Saved stylized image to: outputs/monet_stylev2\0435dc46a4.jpg
# Saved stylized image to: outputs/monet_stylev2\0436aaaf16.jpg
# Saved stylized image to: outputs/monet_stylev2\04387e4338.jpg
# Saved stylized image to: outputs/monet_stylev2\043b541b77.jpg
# Saved stylized image to: outputs/monet_stylev2\044c1653cf.jpg
# Saved stylized image to: outputs/monet_stylev2\0450d4f8ae.jpg
# Saved stylized image to: outputs/monet_stylev2\0451cdb867.jpg
# Saved stylized image to: outputs/monet_stylev2\045e937903.jpg
# Saved stylized image to: outputs/monet_stylev2\0466d4cdf9.jpg
# Saved stylized image to: outputs/monet_stylev2\0473a25050.jpg
# Saved stylized image to: outputs/monet_stylev2\047acab66b.jpg
# Saved stylized image to: outputs/monet_stylev2\047da870f6.jpg
# Saved stylized image to: outputs/monet_stylev2\04838b8b1e.jpg
# Saved stylized image to: outputs/monet_stylev2\049576d31c.jpg
# Saved stylized image to: outputs/monet_stylev2\049b0ece59.jpg
# Saved stylized image to: outputs/monet_stylev2\04a5fc42e1.jpg
# Saved stylized image to: outputs/monet_stylev2\04b8bfdb1c.jpg
# Saved stylized image to: outputs/monet_stylev2\04cb1f4705.jpg
# Saved stylized image to: outputs/monet_stylev2\04cf8e6d5f.jpg
# Saved stylized image to: outputs/monet_stylev2\04d7e14fbe.jpg
# Saved stylized image to: outputs/monet_stylev2\04d91d7bda.jpg
# Saved stylized image to: outputs/monet_stylev2\04e32c4dc1.jpg
# Saved stylized image to: outputs/monet_stylev2\04ec8c9ec2.jpg
# Saved stylized image to: outputs/monet_stylev2\04f59976b5.jpg
# Saved stylized image to: outputs/monet_stylev2\04f71da37b.jpg
# Saved stylized image to: outputs/monet_stylev2\04f72d81b0.jpg
# Saved stylized image to: outputs/monet_stylev2\04f80539d7.jpg
# Saved stylized image to: outputs/monet_stylev2\04fa2a606d.jpg
# Saved stylized image to: outputs/monet_stylev2\04fa456bc9.jpg
# Saved stylized image to: outputs/monet_stylev2\05057d04f7.jpg
# Saved stylized image to: outputs/monet_stylev2\0506726dbd.jpg
# Saved stylized image to: outputs/monet_stylev2\050da171c0.jpg
# Saved stylized image to: outputs/monet_stylev2\051159e33a.jpg
# Saved stylized image to: outputs/monet_stylev2\051a7c9ae6.jpg
# Saved stylized image to: outputs/monet_stylev2\051bde8166.jpg
# Saved stylized image to: outputs/monet_stylev2\051c1b5ee3.jpg
# Saved stylized image to: outputs/monet_stylev2\0529dd48c8.jpg
# Saved stylized image to: outputs/monet_stylev2\053024baa2.jpg
# Saved stylized image to: outputs/monet_stylev2\0541ce0c1a.jpg
# Saved stylized image to: outputs/monet_stylev2\0547a52b93.jpg
# Saved stylized image to: outputs/monet_stylev2\054f264b2e.jpg
# Saved stylized image to: outputs/monet_stylev2\054f375c69.jpg
# Saved stylized image to: outputs/monet_stylev2\05557b0148.jpg
# Saved stylized image to: outputs/monet_stylev2\055c3026f8.jpg
# Saved stylized image to: outputs/monet_stylev2\055dac1e18.jpg
# Saved stylized image to: outputs/monet_stylev2\055e5dca6e.jpg
# Saved stylized image to: outputs/monet_stylev2\05646c5cdb.jpg
# Saved stylized image to: outputs/monet_stylev2\0572f32305.jpg
# Saved stylized image to: outputs/monet_stylev2\057d83cdee.jpg
# Saved stylized image to: outputs/monet_stylev2\058af422c6.jpg
# Saved stylized image to: outputs/monet_stylev2\0597c38d69.jpg
# Saved stylized image to: outputs/monet_stylev2\05a3801bed.jpg
# Saved stylized image to: outputs/monet_stylev2\05a84fad61.jpg
# Saved stylized image to: outputs/monet_stylev2\05c885c810.jpg
# Saved stylized image to: outputs/monet_stylev2\05ca68299e.jpg
# Saved stylized image to: outputs/monet_stylev2\05e37a8900.jpg
# Saved stylized image to: outputs/monet_stylev2\05e88ecd0a.jpg
# Saved stylized image to: outputs/monet_stylev2\05f0db4d14.jpg
# Saved stylized image to: outputs/monet_stylev2\05f22b97da.jpg
# Saved stylized image to: outputs/monet_stylev2\05f4b38e6e.jpg
# Saved stylized image to: outputs/monet_stylev2\06058e6cb0.jpg
# Saved stylized image to: outputs/monet_stylev2\0606110c45.jpg
# Saved stylized image to: outputs/monet_stylev2\061bb611e0.jpg
# Saved stylized image to: outputs/monet_stylev2\061f0095f0.jpg
# Saved stylized image to: outputs/monet_stylev2\062313a97c.jpg
# Saved stylized image to: outputs/monet_stylev2\06371834cb.jpg
# Saved stylized image to: outputs/monet_stylev2\063ab57d41.jpg
# Saved stylized image to: outputs/monet_stylev2\064b9119de.jpg
# Saved stylized image to: outputs/monet_stylev2\064babb7f0.jpg
# Saved stylized image to: outputs/monet_stylev2\064f91250d.jpg
# Saved stylized image to: outputs/monet_stylev2\065b649ac7.jpg
# Saved stylized image to: outputs/monet_stylev2\0665264678.jpg
# Saved stylized image to: outputs/monet_stylev2\066b81e0f9.jpg
# Saved stylized image to: outputs/monet_stylev2\068381ad63.jpg
# Saved stylized image to: outputs/monet_stylev2\068cc6fe3f.jpg
# Saved stylized image to: outputs/monet_stylev2\0696f8142e.jpg
# Saved stylized image to: outputs/monet_stylev2\069e6e5b82.jpg
# Saved stylized image to: outputs/monet_stylev2\06a5930183.jpg
# Saved stylized image to: outputs/monet_stylev2\06a9cf2d11.jpg
# Saved stylized image to: outputs/monet_stylev2\06b2c2dfca.jpg
# Saved stylized image to: outputs/monet_stylev2\06b8114f82.jpg
# Saved stylized image to: outputs/monet_stylev2\06c2d19658.jpg
# Saved stylized image to: outputs/monet_stylev2\06c549794b.jpg
# Saved stylized image to: outputs/monet_stylev2\06c89c4c23.jpg
# Saved stylized image to: outputs/monet_stylev2\06c9326c86.jpg
# Saved stylized image to: outputs/monet_stylev2\06e117b31e.jpg
# Saved stylized image to: outputs/monet_stylev2\06e156d8ba.jpg
# Saved stylized image to: outputs/monet_stylev2\06f749912b.jpg
# Saved stylized image to: outputs/monet_stylev2\07054731ab.jpg
# Saved stylized image to: outputs/monet_stylev2\0709ff32ee.jpg
# Saved stylized image to: outputs/monet_stylev2\0711866dcd.jpg
# Saved stylized image to: outputs/monet_stylev2\071c375c2c.jpg
# Saved stylized image to: outputs/monet_stylev2\0723d52098.jpg
# Saved stylized image to: outputs/monet_stylev2\0724805941.jpg
# Saved stylized image to: outputs/monet_stylev2\072f1336c9.jpg
# Saved stylized image to: outputs/monet_stylev2\07362b3f42.jpg
# Saved stylized image to: outputs/monet_stylev2\073e8b3056.jpg
# Saved stylized image to: outputs/monet_stylev2\074218de82.jpg
# Saved stylized image to: outputs/monet_stylev2\074ea8cb6e.jpg
# Saved stylized image to: outputs/monet_stylev2\07573a95f6.jpg
# Saved stylized image to: outputs/monet_stylev2\075e8d4617.jpg
# Saved stylized image to: outputs/monet_stylev2\0761281e3b.jpg
# Saved stylized image to: outputs/monet_stylev2\076c62582d.jpg
# Saved stylized image to: outputs/monet_stylev2\0770ea1a07.jpg
# Saved stylized image to: outputs/monet_stylev2\077bf7e451.jpg
# Saved stylized image to: outputs/monet_stylev2\078cd3ce07.jpg
# Saved stylized image to: outputs/monet_stylev2\078fd1bc42.jpg
# Saved stylized image to: outputs/monet_stylev2\07939b1fde.jpg
# Saved stylized image to: outputs/monet_stylev2\079da3af1e.jpg
# Saved stylized image to: outputs/monet_stylev2\07b7fdff1b.jpg
# Saved stylized image to: outputs/monet_stylev2\07bf7d7df1.jpg
# Saved stylized image to: outputs/monet_stylev2\07cb260548.jpg
# Saved stylized image to: outputs/monet_stylev2\07e9bc5956.jpg
# Saved stylized image to: outputs/monet_stylev2\07ea3a38d2.jpg
# Saved stylized image to: outputs/monet_stylev2\07f37dfe50.jpg
# Saved stylized image to: outputs/monet_stylev2\07f730ef9a.jpg
# Saved stylized image to: outputs/monet_stylev2\08009f0be5.jpg
# Saved stylized image to: outputs/monet_stylev2\0811c84b0c.jpg
# Saved stylized image to: outputs/monet_stylev2\081955febb.jpg
# Saved stylized image to: outputs/monet_stylev2\08247a7020.jpg
# Saved stylized image to: outputs/monet_stylev2\082786cc1f.jpg
# Saved stylized image to: outputs/monet_stylev2\08341635fa.jpg
# Saved stylized image to: outputs/monet_stylev2\0844c2cddf.jpg
# Saved stylized image to: outputs/monet_stylev2\0845e8dc24.jpg
# Saved stylized image to: outputs/monet_stylev2\085c73097f.jpg
# Saved stylized image to: outputs/monet_stylev2\0860f1e141.jpg
# Saved stylized image to: outputs/monet_stylev2\08645ef69b.jpg
# Saved stylized image to: outputs/monet_stylev2\087e779e73.jpg
# Saved stylized image to: outputs/monet_stylev2\08874a6ee1.jpg
# Saved stylized image to: outputs/monet_stylev2\088972cf3f.jpg
# Saved stylized image to: outputs/monet_stylev2\089406822c.jpg
# Saved stylized image to: outputs/monet_stylev2\08a203b59d.jpg
# Saved stylized image to: outputs/monet_stylev2\08acc490a3.jpg
# Saved stylized image to: outputs/monet_stylev2\08b790bca7.jpg
# Saved stylized image to: outputs/monet_stylev2\08c1754f70.jpg
# Saved stylized image to: outputs/monet_stylev2\08cbd0d6c4.jpg
# Saved stylized image to: outputs/monet_stylev2\08cbd51033.jpg
# Saved stylized image to: outputs/monet_stylev2\08d7603c9c.jpg
# Saved stylized image to: outputs/monet_stylev2\08da1e5774.jpg
# Saved stylized image to: outputs/monet_stylev2\08e3354189.jpg
# Saved stylized image to: outputs/monet_stylev2\08fa88c02c.jpg
# Saved stylized image to: outputs/monet_stylev2\08fa8a6f26.jpg
# Saved stylized image to: outputs/monet_stylev2\08fd7ac09b.jpg
# Saved stylized image to: outputs/monet_stylev2\090d5b3cca.jpg
# Saved stylized image to: outputs/monet_stylev2\091b6b9b07.jpg
# Saved stylized image to: outputs/monet_stylev2\0922bbb3c1.jpg
# Saved stylized image to: outputs/monet_stylev2\0932ad9605.jpg
# Saved stylized image to: outputs/monet_stylev2\0938dc0298.jpg
# Saved stylized image to: outputs/monet_stylev2\0939723138.jpg
# Saved stylized image to: outputs/monet_stylev2\093be92a48.jpg
# Saved stylized image to: outputs/monet_stylev2\093e24f728.jpg
# Saved stylized image to: outputs/monet_stylev2\0945008455.jpg
# Saved stylized image to: outputs/monet_stylev2\09591edd0a.jpg
# Saved stylized image to: outputs/monet_stylev2\095bc5a33d.jpg
# Saved stylized image to: outputs/monet_stylev2\096165f6f0.jpg
# Saved stylized image to: outputs/monet_stylev2\0962094f25.jpg
# Saved stylized image to: outputs/monet_stylev2\0963accefe.jpg
# Saved stylized image to: outputs/monet_stylev2\096495c50c.jpg
# Saved stylized image to: outputs/monet_stylev2\096bae8cd9.jpg
# Saved stylized image to: outputs/monet_stylev2\096da37ff7.jpg
# Saved stylized image to: outputs/monet_stylev2\096f009762.jpg
# Saved stylized image to: outputs/monet_stylev2\09748274a3.jpg
# Saved stylized image to: outputs/monet_stylev2\09756af6f7.jpg
# Saved stylized image to: outputs/monet_stylev2\097b3ce81a.jpg
# Saved stylized image to: outputs/monet_stylev2\097d38ef3b.jpg
# Saved stylized image to: outputs/monet_stylev2\09816286d3.jpg
# Saved stylized image to: outputs/monet_stylev2\0984136f36.jpg
# Saved stylized image to: outputs/monet_stylev2\098b35d919.jpg
# Saved stylized image to: outputs/monet_stylev2\098c0ce670.jpg
# Saved stylized image to: outputs/monet_stylev2\098fde2b22.jpg
# Saved stylized image to: outputs/monet_stylev2\099159901a.jpg
# Saved stylized image to: outputs/monet_stylev2\099395535c.jpg
# Saved stylized image to: outputs/monet_stylev2\09986b5a14.jpg
# Saved stylized image to: outputs/monet_stylev2\09a43d2264.jpg
# Saved stylized image to: outputs/monet_stylev2\09bebf108f.jpg
# Saved stylized image to: outputs/monet_stylev2\09c874df81.jpg
# Saved stylized image to: outputs/monet_stylev2\09d34f7412.jpg
# Saved stylized image to: outputs/monet_stylev2\09ddb5e4c9.jpg
# Saved stylized image to: outputs/monet_stylev2\09e084658a.jpg
# Saved stylized image to: outputs/monet_stylev2\09e1b696b4.jpg
# Saved stylized image to: outputs/monet_stylev2\09e2982b82.jpg
# Saved stylized image to: outputs/monet_stylev2\09e8393bd1.jpg
# Saved stylized image to: outputs/monet_stylev2\09ec565e3a.jpg
# Saved stylized image to: outputs/monet_stylev2\09f57ab8c5.jpg
# Saved stylized image to: outputs/monet_stylev2\09fc404e31.jpg
# Saved stylized image to: outputs/monet_stylev2\09fcd10b7e.jpg
# Saved stylized image to: outputs/monet_stylev2\0a0c3a6d07.jpg
# Saved stylized image to: outputs/monet_stylev2\0a0d3e6ea7.jpg
# Saved stylized image to: outputs/monet_stylev2\0a1d1b9f8e.jpg
# Saved stylized image to: outputs/monet_stylev2\0a271892d0.jpg
# Saved stylized image to: outputs/monet_stylev2\0a284dbed0.jpg
# Saved stylized image to: outputs/monet_stylev2\0a2e5f728d.jpg
# Saved stylized image to: outputs/monet_stylev2\0a325fc655.jpg
# Saved stylized image to: outputs/monet_stylev2\0a44c8287d.jpg
# Saved stylized image to: outputs/monet_stylev2\0a49020ae5.jpg
# Saved stylized image to: outputs/monet_stylev2\0a497f768d.jpg
# Saved stylized image to: outputs/monet_stylev2\0a6091114d.jpg
# Saved stylized image to: outputs/monet_stylev2\0a6279ef66.jpg
# Saved stylized image to: outputs/monet_stylev2\0a6e92d928.jpg
# Saved stylized image to: outputs/monet_stylev2\0a74701f65.jpg
# Saved stylized image to: outputs/monet_stylev2\0a7a8e30bd.jpg
# Saved stylized image to: outputs/monet_stylev2\0a7b607c9c.jpg
# Saved stylized image to: outputs/monet_stylev2\0a8839fac9.jpg
# Saved stylized image to: outputs/monet_stylev2\0a996d988b.jpg
# Saved stylized image to: outputs/monet_stylev2\0aa4202c77.jpg
# Saved stylized image to: outputs/monet_stylev2\0aaf6960c4.jpg
# Saved stylized image to: outputs/monet_stylev2\0abbeddf71.jpg
# Saved stylized image to: outputs/monet_stylev2\0abbf2fd4b.jpg
# Saved stylized image to: outputs/monet_stylev2\0ac4b6aaaa.jpg
# Saved stylized image to: outputs/monet_stylev2\0ac84db7bc.jpg
# Saved stylized image to: outputs/monet_stylev2\0ad13029a9.jpg
# Saved stylized image to: outputs/monet_stylev2\0ad956708f.jpg
# Saved stylized image to: outputs/monet_stylev2\0ae5e9bfe2.jpg
# Saved stylized image to: outputs/monet_stylev2\0aec1f9701.jpg
# Saved stylized image to: outputs/monet_stylev2\0b0bf6fe85.jpg
# Saved stylized image to: outputs/monet_stylev2\0b1669c3ea.jpg
# Saved stylized image to: outputs/monet_stylev2\0b21ce3df6.jpg
# Saved stylized image to: outputs/monet_stylev2\0b2454f0e3.jpg
# Saved stylized image to: outputs/monet_stylev2\0b2f2a3e59.jpg
# Saved stylized image to: outputs/monet_stylev2\0b3fd12ac9.jpg
# Saved stylized image to: outputs/monet_stylev2\0b461ab035.jpg
# Saved stylized image to: outputs/monet_stylev2\0b48073b83.jpg
# Saved stylized image to: outputs/monet_stylev2\0b4dbff7c8.jpg
# Saved stylized image to: outputs/monet_stylev2\0b4f93c337.jpg
# Saved stylized image to: outputs/monet_stylev2\0b53fd3e90.jpg
# Saved stylized image to: outputs/monet_stylev2\0b68939003.jpg
# Saved stylized image to: outputs/monet_stylev2\0b6b4bfc29.jpg
# Saved stylized image to: outputs/monet_stylev2\0b91f359c5.jpg
# Saved stylized image to: outputs/monet_stylev2\0b97d70d93.jpg
# Saved stylized image to: outputs/monet_stylev2\0bb9d1a3cf.jpg
# Saved stylized image to: outputs/monet_stylev2\0bcecb1330.jpg
# Saved stylized image to: outputs/monet_stylev2\0bddd37684.jpg
# Saved stylized image to: outputs/monet_stylev2\0bde6ba99b.jpg
# Saved stylized image to: outputs/monet_stylev2\0bdf3110dc.jpg
# Saved stylized image to: outputs/monet_stylev2\0bede4ba4e.jpg
# Saved stylized image to: outputs/monet_stylev2\0c18bf8536.jpg
# Saved stylized image to: outputs/monet_stylev2\0c21bed0d8.jpg
# Saved stylized image to: outputs/monet_stylev2\0c272fcde8.jpg
# Saved stylized image to: outputs/monet_stylev2\0c4ebc7f6a.jpg
# Saved stylized image to: outputs/monet_stylev2\0c64451f58.jpg
# Saved stylized image to: outputs/monet_stylev2\0c64b00832.jpg
# Saved stylized image to: outputs/monet_stylev2\0c696d12a2.jpg
# Saved stylized image to: outputs/monet_stylev2\0c6b56bba9.jpg
# Saved stylized image to: outputs/monet_stylev2\0c6b63c2c5.jpg
# Saved stylized image to: outputs/monet_stylev2\0c6c9d8ce7.jpg
# Saved stylized image to: outputs/monet_stylev2\0c6e6b52be.jpg
# Saved stylized image to: outputs/monet_stylev2\0c6fcdf1f5.jpg
# Saved stylized image to: outputs/monet_stylev2\0c781e1538.jpg
# Saved stylized image to: outputs/monet_stylev2\0c7e07acd3.jpg
# Saved stylized image to: outputs/monet_stylev2\0c8a94c597.jpg
# Saved stylized image to: outputs/monet_stylev2\0ca5b3c96a.jpg
# Saved stylized image to: outputs/monet_stylev2\0cac1bcf2b.jpg
# Saved stylized image to: outputs/monet_stylev2\0cae98323f.jpg
# Saved stylized image to: outputs/monet_stylev2\0cb4144fbb.jpg
# Saved stylized image to: outputs/monet_stylev2\0cb6683555.jpg
# Saved stylized image to: outputs/monet_stylev2\0ccbcfcf65.jpg
# Saved stylized image to: outputs/monet_stylev2\0cda2627bf.jpg
# Saved stylized image to: outputs/monet_stylev2\0cdfbb28e6.jpg
# Saved stylized image to: outputs/monet_stylev2\0ce227ee32.jpg
# Saved stylized image to: outputs/monet_stylev2\0cec4d02a7.jpg
# Saved stylized image to: outputs/monet_stylev2\0cecce2e24.jpg
# Saved stylized image to: outputs/monet_stylev2\0cf495d82e.jpg
# Saved stylized image to: outputs/monet_stylev2\0cf4dc75d0.jpg
# Saved stylized image to: outputs/monet_stylev2\0cfe85f73d.jpg
# Saved stylized image to: outputs/monet_stylev2\0d11463712.jpg
# Saved stylized image to: outputs/monet_stylev2\0d1a5b6882.jpg
# Saved stylized image to: outputs/monet_stylev2\0d23431254.jpg
# Saved stylized image to: outputs/monet_stylev2\0d2583e3ea.jpg
# Saved stylized image to: outputs/monet_stylev2\0d2ed7fb8e.jpg
# Saved stylized image to: outputs/monet_stylev2\0d2f9d322d.jpg
# Saved stylized image to: outputs/monet_stylev2\0d3752b4ad.jpg
# Saved stylized image to: outputs/monet_stylev2\0d423f52fd.jpg
# Saved stylized image to: outputs/monet_stylev2\0d59054b30.jpg
# Saved stylized image to: outputs/monet_stylev2\0d593e3752.jpg
# Saved stylized image to: outputs/monet_stylev2\0d64ca5ecf.jpg
# Saved stylized image to: outputs/monet_stylev2\0d6ba5d215.jpg
# Saved stylized image to: outputs/monet_stylev2\0d6c81cbc2.jpg
# Saved stylized image to: outputs/monet_stylev2\0d6f893bc7.jpg
# Saved stylized image to: outputs/monet_stylev2\0d7c5d97ac.jpg
# Saved stylized image to: outputs/monet_stylev2\0d80b97eb4.jpg
# Saved stylized image to: outputs/monet_stylev2\0d859e1630.jpg
# Saved stylized image to: outputs/monet_stylev2\0d89393fe0.jpg
# Saved stylized image to: outputs/monet_stylev2\0d8c66b24e.jpg
# Saved stylized image to: outputs/monet_stylev2\0dd016afa5.jpg
# Saved stylized image to: outputs/monet_stylev2\0dd4041294.jpg
# Saved stylized image to: outputs/monet_stylev2\0dd5085fdf.jpg
# Saved stylized image to: outputs/monet_stylev2\0dde3f8ee7.jpg
# Saved stylized image to: outputs/monet_stylev2\0de8320918.jpg
# Saved stylized image to: outputs/monet_stylev2\0de920c5bf.jpg
# Saved stylized image to: outputs/monet_stylev2\0debce885b.jpg
# Saved stylized image to: outputs/monet_stylev2\0df35db4a2.jpg
# Saved stylized image to: outputs/monet_stylev2\0df9a45c26.jpg
# Saved stylized image to: outputs/monet_stylev2\0e003670f7.jpg
# Saved stylized image to: outputs/monet_stylev2\0e0577ec3a.jpg
# Saved stylized image to: outputs/monet_stylev2\0e0a660bb8.jpg
# Saved stylized image to: outputs/monet_stylev2\0e0bdef20a.jpg
# Saved stylized image to: outputs/monet_stylev2\0e1230a330.jpg
# Saved stylized image to: outputs/monet_stylev2\0e13d9c6f4.jpg
# Saved stylized image to: outputs/monet_stylev2\0e23057337.jpg
# Saved stylized image to: outputs/monet_stylev2\0e2610ef33.jpg
# Saved stylized image to: outputs/monet_stylev2\0e441b3c17.jpg
# Saved stylized image to: outputs/monet_stylev2\0e4c7d5e15.jpg
# Saved stylized image to: outputs/monet_stylev2\0e4ec46846.jpg
# Saved stylized image to: outputs/monet_stylev2\0e5afbada4.jpg
# Saved stylized image to: outputs/monet_stylev2\0e750aaed9.jpg
# Saved stylized image to: outputs/monet_stylev2\0e8eb4587e.jpg
# Saved stylized image to: outputs/monet_stylev2\0e95c87f76.jpg
# Saved stylized image to: outputs/monet_stylev2\0e983a3ef5.jpg
# Saved stylized image to: outputs/monet_stylev2\0eaa8d71f6.jpg
# Saved stylized image to: outputs/monet_stylev2\0eb3c8892a.jpg
# Saved stylized image to: outputs/monet_stylev2\0eb810429d.jpg
# Saved stylized image to: outputs/monet_stylev2\0eddbbb35c.jpg
# Saved stylized image to: outputs/monet_stylev2\0f1e6530bc.jpg
# Saved stylized image to: outputs/monet_stylev2\0f35be9cbb.jpg
# Saved stylized image to: outputs/monet_stylev2\0f3757e6cd.jpg
# Saved stylized image to: outputs/monet_stylev2\0f3ed210c0.jpg
# Saved stylized image to: outputs/monet_stylev2\0f5228f2a6.jpg
# Saved stylized image to: outputs/monet_stylev2\0f58899ce1.jpg
# Saved stylized image to: outputs/monet_stylev2\0f819ab838.jpg
# Saved stylized image to: outputs/monet_stylev2\0f8e316a87.jpg
# Saved stylized image to: outputs/monet_stylev2\0fa29829f2.jpg
# Saved stylized image to: outputs/monet_stylev2\0fa5629898.jpg
# Saved stylized image to: outputs/monet_stylev2\0fb1ca7fe1.jpg
# Saved stylized image to: outputs/monet_stylev2\0fbcbeddd5.jpg
# Saved stylized image to: outputs/monet_stylev2\0fca1c304e.jpg
# Saved stylized image to: outputs/monet_stylev2\0fccbd8558.jpg
# Saved stylized image to: outputs/monet_stylev2\0fd7cd6092.jpg
# Saved stylized image to: outputs/monet_stylev2\0fdcf56678.jpg
# Saved stylized image to: outputs/monet_stylev2\0fe76a9ec9.jpg
# Saved stylized image to: outputs/monet_stylev2\0fef77210a.jpg
# Saved stylized image to: outputs/monet_stylev2\10118ae431.jpg
# Saved stylized image to: outputs/monet_stylev2\101a1f34db.jpg
# Saved stylized image to: outputs/monet_stylev2\101a5ad83d.jpg
# Saved stylized image to: outputs/monet_stylev2\101c59feab.jpg
# Saved stylized image to: outputs/monet_stylev2\101d00677e.jpg
# Saved stylized image to: outputs/monet_stylev2\102c9065a7.jpg
# Saved stylized image to: outputs/monet_stylev2\102da9e0bf.jpg
# Saved stylized image to: outputs/monet_stylev2\10371b9044.jpg
# Saved stylized image to: outputs/monet_stylev2\1037993785.jpg
# Saved stylized image to: outputs/monet_stylev2\104204fa3f.jpg
# Saved stylized image to: outputs/monet_stylev2\105ac2e395.jpg
# Saved stylized image to: outputs/monet_stylev2\106091e966.jpg
# Saved stylized image to: outputs/monet_stylev2\1064e8c2fc.jpg
# Saved stylized image to: outputs/monet_stylev2\10729e0962.jpg
# Saved stylized image to: outputs/monet_stylev2\1076bdc405.jpg
# Saved stylized image to: outputs/monet_stylev2\107769ed33.jpg
# Saved stylized image to: outputs/monet_stylev2\1079a7abe1.jpg
# Saved stylized image to: outputs/monet_stylev2\108d3336bd.jpg
# Saved stylized image to: outputs/monet_stylev2\108f57c580.jpg
# Saved stylized image to: outputs/monet_stylev2\1097dcc82e.jpg
# Saved stylized image to: outputs/monet_stylev2\10ab9fcfcb.jpg
# Saved stylized image to: outputs/monet_stylev2\10e101cae7.jpg
# Saved stylized image to: outputs/monet_stylev2\10e79c0f04.jpg
# Saved stylized image to: outputs/monet_stylev2\10f3bc8893.jpg
# Saved stylized image to: outputs/monet_stylev2\1106610965.jpg
# Saved stylized image to: outputs/monet_stylev2\11068aa40b.jpg
# Saved stylized image to: outputs/monet_stylev2\110d660fee.jpg
# Saved stylized image to: outputs/monet_stylev2\112f088373.jpg
# Saved stylized image to: outputs/monet_stylev2\113444c0c2.jpg
# Saved stylized image to: outputs/monet_stylev2\1138db3be9.jpg
# Saved stylized image to: outputs/monet_stylev2\114692dc5b.jpg
# Saved stylized image to: outputs/monet_stylev2\1151c9b98d.jpg
# Saved stylized image to: outputs/monet_stylev2\115cd21c1c.jpg
# Saved stylized image to: outputs/monet_stylev2\115cd80f74.jpg
# Saved stylized image to: outputs/monet_stylev2\115f221c2a.jpg
# Saved stylized image to: outputs/monet_stylev2\115f43bae3.jpg
# Saved stylized image to: outputs/monet_stylev2\117281b37b.jpg
# Saved stylized image to: outputs/monet_stylev2\1172d3e228.jpg
# Saved stylized image to: outputs/monet_stylev2\117d70bd19.jpg
# Saved stylized image to: outputs/monet_stylev2\117e2a807d.jpg
# Saved stylized image to: outputs/monet_stylev2\1193c043d7.jpg
# Saved stylized image to: outputs/monet_stylev2\11bcbf0f67.jpg
# Saved stylized image to: outputs/monet_stylev2\11c1de8b75.jpg
# Saved stylized image to: outputs/monet_stylev2\11c24d756f.jpg
# Saved stylized image to: outputs/monet_stylev2\11cc678dbf.jpg
# Saved stylized image to: outputs/monet_stylev2\11d4cd762d.jpg
# Saved stylized image to: outputs/monet_stylev2\11d713b4ee.jpg
# Saved stylized image to: outputs/monet_stylev2\11e25d3dc4.jpg
# Saved stylized image to: outputs/monet_stylev2\11f13ca69e.jpg
# Saved stylized image to: outputs/monet_stylev2\11f482a716.jpg
# Saved stylized image to: outputs/monet_stylev2\11feb29e6a.jpg
# Saved stylized image to: outputs/monet_stylev2\1216dc1ffe.jpg
# Saved stylized image to: outputs/monet_stylev2\12193672ba.jpg
# Saved stylized image to: outputs/monet_stylev2\122f944d40.jpg
# Saved stylized image to: outputs/monet_stylev2\1235e32fb2.jpg
# Saved stylized image to: outputs/monet_stylev2\123714f71c.jpg
# Saved stylized image to: outputs/monet_stylev2\1240cc6f83.jpg
# Saved stylized image to: outputs/monet_stylev2\124244310e.jpg
# Saved stylized image to: outputs/monet_stylev2\124dda3622.jpg
# Saved stylized image to: outputs/monet_stylev2\125fd9187b.jpg
# Saved stylized image to: outputs/monet_stylev2\12672ab41c.jpg
# Saved stylized image to: outputs/monet_stylev2\126fb64cb8.jpg
# Saved stylized image to: outputs/monet_stylev2\1285f93747.jpg
# Saved stylized image to: outputs/monet_stylev2\129823154f.jpg
# Saved stylized image to: outputs/monet_stylev2\129df5c60c.jpg
# Saved stylized image to: outputs/monet_stylev2\12ae4ffbb5.jpg
# Saved stylized image to: outputs/monet_stylev2\12b2a8d1fc.jpg
# Saved stylized image to: outputs/monet_stylev2\12b302b5f1.jpg
# Saved stylized image to: outputs/monet_stylev2\12c5ce9b42.jpg
# Saved stylized image to: outputs/monet_stylev2\12c65cd54c.jpg
# Saved stylized image to: outputs/monet_stylev2\12cb4d2917.jpg
# Saved stylized image to: outputs/monet_stylev2\12cc0ffc15.jpg
# Saved stylized image to: outputs/monet_stylev2\12d0476b93.jpg
# Saved stylized image to: outputs/monet_stylev2\12e9b80b70.jpg
# Saved stylized image to: outputs/monet_stylev2\12f09c6efe.jpg
# Saved stylized image to: outputs/monet_stylev2\12f74378d4.jpg
# Saved stylized image to: outputs/monet_stylev2\12f9c1a7b5.jpg
# Saved stylized image to: outputs/monet_stylev2\13048dfacf.jpg
# Saved stylized image to: outputs/monet_stylev2\13173bc6b5.jpg
# Saved stylized image to: outputs/monet_stylev2\13219b2462.jpg
# Saved stylized image to: outputs/monet_stylev2\13328c1504.jpg
# Saved stylized image to: outputs/monet_stylev2\133adbd41e.jpg
# Saved stylized image to: outputs/monet_stylev2\134f611db2.jpg
# Saved stylized image to: outputs/monet_stylev2\1355735108.jpg
# Saved stylized image to: outputs/monet_stylev2\1363fc8268.jpg
# Saved stylized image to: outputs/monet_stylev2\1365922bc1.jpg
# Saved stylized image to: outputs/monet_stylev2\13671d11f9.jpg
# Saved stylized image to: outputs/monet_stylev2\1379cdd516.jpg
# Saved stylized image to: outputs/monet_stylev2\13829b20dd.jpg
# Saved stylized image to: outputs/monet_stylev2\13888541b7.jpg
# Saved stylized image to: outputs/monet_stylev2\13892d15e5.jpg
# Saved stylized image to: outputs/monet_stylev2\138a069c6c.jpg
# Saved stylized image to: outputs/monet_stylev2\138c350c89.jpg
# Saved stylized image to: outputs/monet_stylev2\13bbd45d01.jpg
# Saved stylized image to: outputs/monet_stylev2\13c0555eab.jpg
# Saved stylized image to: outputs/monet_stylev2\13c3b0e711.jpg
# Saved stylized image to: outputs/monet_stylev2\13e3480e01.jpg
# Saved stylized image to: outputs/monet_stylev2\13f4f7168a.jpg
# Saved stylized image to: outputs/monet_stylev2\13fec527bb.jpg
# Saved stylized image to: outputs/monet_stylev2\140f195fbc.jpg
# Saved stylized image to: outputs/monet_stylev2\14135c74d7.jpg
# Saved stylized image to: outputs/monet_stylev2\141ade2afb.jpg
# Saved stylized image to: outputs/monet_stylev2\1421d11393.jpg
# Saved stylized image to: outputs/monet_stylev2\142cda27d9.jpg
# Saved stylized image to: outputs/monet_stylev2\1432b7355d.jpg
# Saved stylized image to: outputs/monet_stylev2\1437a4d5f9.jpg
# Saved stylized image to: outputs/monet_stylev2\1444ac5586.jpg
# Saved stylized image to: outputs/monet_stylev2\1451c82e2f.jpg
# Saved stylized image to: outputs/monet_stylev2\1467b3a6ac.jpg
# Saved stylized image to: outputs/monet_stylev2\1476b02998.jpg
# Saved stylized image to: outputs/monet_stylev2\14804e18f9.jpg
# Saved stylized image to: outputs/monet_stylev2\14860c3bed.jpg
# Saved stylized image to: outputs/monet_stylev2\1491d9367b.jpg
# Saved stylized image to: outputs/monet_stylev2\1499400929.jpg
# Saved stylized image to: outputs/monet_stylev2\149e367310.jpg
# Saved stylized image to: outputs/monet_stylev2\14a7686f98.jpg
# Saved stylized image to: outputs/monet_stylev2\14a95bb688.jpg
# Saved stylized image to: outputs/monet_stylev2\14ac55e78e.jpg
# Saved stylized image to: outputs/monet_stylev2\14b92a85f3.jpg
# Saved stylized image to: outputs/monet_stylev2\14bcc3cdad.jpg
# Saved stylized image to: outputs/monet_stylev2\14c0e95507.jpg
# Saved stylized image to: outputs/monet_stylev2\14c38e1c2e.jpg
# Saved stylized image to: outputs/monet_stylev2\14fa7a9b31.jpg
# Saved stylized image to: outputs/monet_stylev2\14fe889824.jpg
# Saved stylized image to: outputs/monet_stylev2\151cb3c6ff.jpg
# Saved stylized image to: outputs/monet_stylev2\1531eae642.jpg
# Saved stylized image to: outputs/monet_stylev2\153bb660da.jpg
# Saved stylized image to: outputs/monet_stylev2\153e1ec171.jpg
# Saved stylized image to: outputs/monet_stylev2\153f59d4cb.jpg
# Saved stylized image to: outputs/monet_stylev2\156540ebe1.jpg
# Saved stylized image to: outputs/monet_stylev2\1569489edb.jpg
# Saved stylized image to: outputs/monet_stylev2\156cf5822e.jpg
# Saved stylized image to: outputs/monet_stylev2\15769de345.jpg
# Saved stylized image to: outputs/monet_stylev2\157ee68b71.jpg
# Saved stylized image to: outputs/monet_stylev2\1581f3755e.jpg
# Saved stylized image to: outputs/monet_stylev2\1582ec589d.jpg
# Saved stylized image to: outputs/monet_stylev2\159b3f002f.jpg
# Saved stylized image to: outputs/monet_stylev2\159baa9c2b.jpg
# Saved stylized image to: outputs/monet_stylev2\159c19456b.jpg
# Saved stylized image to: outputs/monet_stylev2\159e0baf13.jpg
# Saved stylized image to: outputs/monet_stylev2\15a51e4dbe.jpg
# Saved stylized image to: outputs/monet_stylev2\15a9b54b5f.jpg
# Saved stylized image to: outputs/monet_stylev2\15abe5af92.jpg
# Saved stylized image to: outputs/monet_stylev2\15b1f01b86.jpg
# Saved stylized image to: outputs/monet_stylev2\15b9563151.jpg
# Saved stylized image to: outputs/monet_stylev2\15cb21df1a.jpg
# Saved stylized image to: outputs/monet_stylev2\15cca6975b.jpg
# Saved stylized image to: outputs/monet_stylev2\15d8655b4f.jpg
# Saved stylized image to: outputs/monet_stylev2\15f7238855.jpg
# Saved stylized image to: outputs/monet_stylev2\15f862b305.jpg
# Saved stylized image to: outputs/monet_stylev2\160c560e5e.jpg
# Saved stylized image to: outputs/monet_stylev2\160d920b63.jpg
# Saved stylized image to: outputs/monet_stylev2\1615de2bd0.jpg
# Saved stylized image to: outputs/monet_stylev2\161b3c519e.jpg
# Saved stylized image to: outputs/monet_stylev2\163669cbd0.jpg
# Saved stylized image to: outputs/monet_stylev2\164492cfa7.jpg
# Saved stylized image to: outputs/monet_stylev2\1645d08cab.jpg
# Saved stylized image to: outputs/monet_stylev2\164ebc7900.jpg
# Saved stylized image to: outputs/monet_stylev2\165dfb6cd0.jpg
# Saved stylized image to: outputs/monet_stylev2\1665a48def.jpg
# Saved stylized image to: outputs/monet_stylev2\1675879297.jpg
# Saved stylized image to: outputs/monet_stylev2\1676f96061.jpg
# Saved stylized image to: outputs/monet_stylev2\1688783462.jpg
# Saved stylized image to: outputs/monet_stylev2\1694e5637b.jpg
# Saved stylized image to: outputs/monet_stylev2\16963c4f89.jpg
# Saved stylized image to: outputs/monet_stylev2\169c381352.jpg
# Saved stylized image to: outputs/monet_stylev2\169f8a8503.jpg
# Saved stylized image to: outputs/monet_stylev2\16a0c8ed23.jpg
# Saved stylized image to: outputs/monet_stylev2\16a3dd9695.jpg
# Saved stylized image to: outputs/monet_stylev2\16a666edff.jpg
# Saved stylized image to: outputs/monet_stylev2\16a7a9fc44.jpg
# Saved stylized image to: outputs/monet_stylev2\16ab6bc622.jpg
# Saved stylized image to: outputs/monet_stylev2\16b3067a86.jpg
# Saved stylized image to: outputs/monet_stylev2\16b3ea1e00.jpg
# Saved stylized image to: outputs/monet_stylev2\16b74bd37f.jpg
# Saved stylized image to: outputs/monet_stylev2\16c119b3c7.jpg
# Saved stylized image to: outputs/monet_stylev2\16cd6cbc68.jpg
# Saved stylized image to: outputs/monet_stylev2\16d8cafb5b.jpg
# Saved stylized image to: outputs/monet_stylev2\16d9624078.jpg
# Saved stylized image to: outputs/monet_stylev2\16de17a9aa.jpg
# Saved stylized image to: outputs/monet_stylev2\16de6b603c.jpg
# Saved stylized image to: outputs/monet_stylev2\16ded6f738.jpg
# Saved stylized image to: outputs/monet_stylev2\16dff1b77f.jpg
# Saved stylized image to: outputs/monet_stylev2\16e764f509.jpg
# Saved stylized image to: outputs/monet_stylev2\16f0c49f22.jpg
# Saved stylized image to: outputs/monet_stylev2\16f3703756.jpg
# Saved stylized image to: outputs/monet_stylev2\1701c26348.jpg
# Saved stylized image to: outputs/monet_stylev2\17028b1e92.jpg
# Saved stylized image to: outputs/monet_stylev2\170434d3dd.jpg
# Saved stylized image to: outputs/monet_stylev2\170dbca136.jpg
# Saved stylized image to: outputs/monet_stylev2\17167ea036.jpg
# Saved stylized image to: outputs/monet_stylev2\172a0707b2.jpg
# Saved stylized image to: outputs/monet_stylev2\17315bdc5b.jpg
# Saved stylized image to: outputs/monet_stylev2\1735a91a3d.jpg
# Saved stylized image to: outputs/monet_stylev2\17398e5a2a.jpg
# Saved stylized image to: outputs/monet_stylev2\17499b0283.jpg
# Saved stylized image to: outputs/monet_stylev2\174ded9426.jpg
# Saved stylized image to: outputs/monet_stylev2\174f0355a6.jpg
# Saved stylized image to: outputs/monet_stylev2\17592a1017.jpg
# Saved stylized image to: outputs/monet_stylev2\176050474a.jpg
# Saved stylized image to: outputs/monet_stylev2\1764393c0e.jpg
# Saved stylized image to: outputs/monet_stylev2\17674de2d5.jpg
# Saved stylized image to: outputs/monet_stylev2\176bec46aa.jpg
# Saved stylized image to: outputs/monet_stylev2\176d0e5c75.jpg
# Saved stylized image to: outputs/monet_stylev2\1771b7c478.jpg
# Saved stylized image to: outputs/monet_stylev2\1774482049.jpg
# Saved stylized image to: outputs/monet_stylev2\1779a8225f.jpg
# Saved stylized image to: outputs/monet_stylev2\1789a61138.jpg
# Saved stylized image to: outputs/monet_stylev2\178d33e084.jpg
# Saved stylized image to: outputs/monet_stylev2\17924dd78d.jpg
# Saved stylized image to: outputs/monet_stylev2\179af606cb.jpg
# Saved stylized image to: outputs/monet_stylev2\17a199a709.jpg
# Saved stylized image to: outputs/monet_stylev2\17a8bd8ba4.jpg
# Saved stylized image to: outputs/monet_stylev2\17b7569c29.jpg
# Saved stylized image to: outputs/monet_stylev2\17c8c9072a.jpg
# Saved stylized image to: outputs/monet_stylev2\17ce3a201d.jpg
# Saved stylized image to: outputs/monet_stylev2\17cf077f45.jpg
# Saved stylized image to: outputs/monet_stylev2\17d4e23d9f.jpg
# Saved stylized image to: outputs/monet_stylev2\17d896fd14.jpg
# Saved stylized image to: outputs/monet_stylev2\17dbf8cf56.jpg
# Saved stylized image to: outputs/monet_stylev2\17e149928d.jpg
# Saved stylized image to: outputs/monet_stylev2\17eb22711b.jpg
# Saved stylized image to: outputs/monet_stylev2\17f8f4d5d9.jpg
# Saved stylized image to: outputs/monet_stylev2\17f92dd71b.jpg
# Saved stylized image to: outputs/monet_stylev2\180e1881bc.jpg
# Saved stylized image to: outputs/monet_stylev2\18162a62a3.jpg
# Saved stylized image to: outputs/monet_stylev2\181a53c38a.jpg
# Saved stylized image to: outputs/monet_stylev2\181f424335.jpg
# Saved stylized image to: outputs/monet_stylev2\182690bc45.jpg
# Saved stylized image to: outputs/monet_stylev2\182846af47.jpg
# Saved stylized image to: outputs/monet_stylev2\1838bcc8fa.jpg
# Saved stylized image to: outputs/monet_stylev2\184a433ce3.jpg
# Saved stylized image to: outputs/monet_stylev2\185f8da469.jpg
# Saved stylized image to: outputs/monet_stylev2\186035e2a8.jpg
# Saved stylized image to: outputs/monet_stylev2\1866c56f7a.jpg
# Saved stylized image to: outputs/monet_stylev2\186e98dcb8.jpg
# Saved stylized image to: outputs/monet_stylev2\1883fcfb3e.jpg
# Saved stylized image to: outputs/monet_stylev2\1884a2a37d.jpg
# Saved stylized image to: outputs/monet_stylev2\18880e913d.jpg
# Saved stylized image to: outputs/monet_stylev2\188b7f6310.jpg
# Saved stylized image to: outputs/monet_stylev2\1893ce79ce.jpg
# Saved stylized image to: outputs/monet_stylev2\1894c178ea.jpg
# Saved stylized image to: outputs/monet_stylev2\1897b7b118.jpg
# Saved stylized image to: outputs/monet_stylev2\189ae3f5a7.jpg
# Saved stylized image to: outputs/monet_stylev2\189ee6859e.jpg
# Saved stylized image to: outputs/monet_stylev2\18a275b358.jpg
# Saved stylized image to: outputs/monet_stylev2\18a4ee0991.jpg
# Saved stylized image to: outputs/monet_stylev2\18aca60c06.jpg
# Saved stylized image to: outputs/monet_stylev2\18ae840f5d.jpg
# Saved stylized image to: outputs/monet_stylev2\18b2d7a2ef.jpg
# Saved stylized image to: outputs/monet_stylev2\18c6b5b73b.jpg
# Saved stylized image to: outputs/monet_stylev2\18ca544c78.jpg
# Saved stylized image to: outputs/monet_stylev2\18e384cfff.jpg
# Saved stylized image to: outputs/monet_stylev2\18e571a627.jpg
# Saved stylized image to: outputs/monet_stylev2\18ea7c98b1.jpg
# Saved stylized image to: outputs/monet_stylev2\190633c073.jpg
# Saved stylized image to: outputs/monet_stylev2\1912f08cb1.jpg
# Saved stylized image to: outputs/monet_stylev2\19182d3849.jpg
# Saved stylized image to: outputs/monet_stylev2\1921b26eea.jpg
# Saved stylized image to: outputs/monet_stylev2\1925109fdd.jpg
# Saved stylized image to: outputs/monet_stylev2\192682abdf.jpg
# Saved stylized image to: outputs/monet_stylev2\192caaa1bf.jpg
# Saved stylized image to: outputs/monet_stylev2\1936e1dcb4.jpg
# Saved stylized image to: outputs/monet_stylev2\193b4cdb27.jpg
# Saved stylized image to: outputs/monet_stylev2\193f3266fb.jpg
# Saved stylized image to: outputs/monet_stylev2\194bb9f6ed.jpg
# Saved stylized image to: outputs/monet_stylev2\19525a17e2.jpg
# Saved stylized image to: outputs/monet_stylev2\19592a5fbf.jpg
# Saved stylized image to: outputs/monet_stylev2\1960283fd5.jpg
# Saved stylized image to: outputs/monet_stylev2\1966101984.jpg
# Saved stylized image to: outputs/monet_stylev2\196a6875a7.jpg
# Saved stylized image to: outputs/monet_stylev2\196e2c07aa.jpg
# Saved stylized image to: outputs/monet_stylev2\1970faab6a.jpg
# Saved stylized image to: outputs/monet_stylev2\1977b66f96.jpg
# Saved stylized image to: outputs/monet_stylev2\197dc21bdb.jpg
# Saved stylized image to: outputs/monet_stylev2\19801ae9ab.jpg
# Saved stylized image to: outputs/monet_stylev2\1986fa52f5.jpg
# Saved stylized image to: outputs/monet_stylev2\198cad00d4.jpg
# Saved stylized image to: outputs/monet_stylev2\19918a1d5c.jpg
# Saved stylized image to: outputs/monet_stylev2\1998700449.jpg
# Saved stylized image to: outputs/monet_stylev2\1999225d11.jpg
# Saved stylized image to: outputs/monet_stylev2\199a3e859f.jpg
# Saved stylized image to: outputs/monet_stylev2\199d0b8782.jpg
# Saved stylized image to: outputs/monet_stylev2\19a7361b2a.jpg
# Saved stylized image to: outputs/monet_stylev2\19b0fbeba0.jpg
# Saved stylized image to: outputs/monet_stylev2\19b944dbbf.jpg
# Saved stylized image to: outputs/monet_stylev2\19b98e5663.jpg
# Saved stylized image to: outputs/monet_stylev2\19bad1225f.jpg
# Saved stylized image to: outputs/monet_stylev2\19bd14d30e.jpg
# Saved stylized image to: outputs/monet_stylev2\19be535e5f.jpg
# Saved stylized image to: outputs/monet_stylev2\19c277c363.jpg
# Saved stylized image to: outputs/monet_stylev2\19c8301d67.jpg
# Saved stylized image to: outputs/monet_stylev2\19e7940d94.jpg
# Saved stylized image to: outputs/monet_stylev2\19e8b9b328.jpg
# Saved stylized image to: outputs/monet_stylev2\1a23085db7.jpg
# Saved stylized image to: outputs/monet_stylev2\1a2542d28b.jpg
# Saved stylized image to: outputs/monet_stylev2\1a25f82753.jpg
# Saved stylized image to: outputs/monet_stylev2\1a27cb4cba.jpg
# Saved stylized image to: outputs/monet_stylev2\1a2cd9ea8c.jpg
# Saved stylized image to: outputs/monet_stylev2\1a3b1a3da9.jpg
# Saved stylized image to: outputs/monet_stylev2\1a4213d2ce.jpg
# Saved stylized image to: outputs/monet_stylev2\1a4491cef2.jpg
# Saved stylized image to: outputs/monet_stylev2\1a45b8c270.jpg
# Saved stylized image to: outputs/monet_stylev2\1a5041d9ed.jpg
# Saved stylized image to: outputs/monet_stylev2\1a5cf3b632.jpg
# Saved stylized image to: outputs/monet_stylev2\1a6013cba4.jpg
# Saved stylized image to: outputs/monet_stylev2\1a61870a06.jpg
# Saved stylized image to: outputs/monet_stylev2\1a6b4e9e13.jpg
# Saved stylized image to: outputs/monet_stylev2\1a7af9964c.jpg
# Saved stylized image to: outputs/monet_stylev2\1a8633fbb9.jpg
# Saved stylized image to: outputs/monet_stylev2\1a892680fb.jpg
# Saved stylized image to: outputs/monet_stylev2\1a8c1a7995.jpg
# Saved stylized image to: outputs/monet_stylev2\1a8c9e6c4c.jpg
# Saved stylized image to: outputs/monet_stylev2\1aa0d1c558.jpg
# Saved stylized image to: outputs/monet_stylev2\1aa8abd685.jpg
# Saved stylized image to: outputs/monet_stylev2\1ac1673452.jpg
# Saved stylized image to: outputs/monet_stylev2\1ac35e7dc8.jpg
# Saved stylized image to: outputs/monet_stylev2\1ac5876376.jpg
# Saved stylized image to: outputs/monet_stylev2\1acb4c14ce.jpg
# Saved stylized image to: outputs/monet_stylev2\1acb4d1d54.jpg
# Saved stylized image to: outputs/monet_stylev2\1ad17703ce.jpg
# Saved stylized image to: outputs/monet_stylev2\1ad8701262.jpg
# Saved stylized image to: outputs/monet_stylev2\1ae03b00e7.jpg
# Saved stylized image to: outputs/monet_stylev2\1ae342cd57.jpg
# Saved stylized image to: outputs/monet_stylev2\1b062b66a7.jpg
# Saved stylized image to: outputs/monet_stylev2\1b118a066b.jpg
# Saved stylized image to: outputs/monet_stylev2\1b129b65db.jpg
# Saved stylized image to: outputs/monet_stylev2\1b12cf626f.jpg
# Saved stylized image to: outputs/monet_stylev2\1b3e398db7.jpg
# Saved stylized image to: outputs/monet_stylev2\1b4e94ffbd.jpg
# Saved stylized image to: outputs/monet_stylev2\1b4f115bdd.jpg
# Saved stylized image to: outputs/monet_stylev2\1b5e8cedda.jpg
# Saved stylized image to: outputs/monet_stylev2\1b66416060.jpg
# Saved stylized image to: outputs/monet_stylev2\1b6a1a7e94.jpg
# Saved stylized image to: outputs/monet_stylev2\1b6d7b4e65.jpg
# Saved stylized image to: outputs/monet_stylev2\1b72549327.jpg
# Saved stylized image to: outputs/monet_stylev2\1b770229f3.jpg
# Saved stylized image to: outputs/monet_stylev2\1b961a3a39.jpg
# Saved stylized image to: outputs/monet_stylev2\1b98321823.jpg
# Saved stylized image to: outputs/monet_stylev2\1b987c577e.jpg
# Saved stylized image to: outputs/monet_stylev2\1baa6a3895.jpg
# Saved stylized image to: outputs/monet_stylev2\1baf74b1a7.jpg
# Saved stylized image to: outputs/monet_stylev2\1bb75f970a.jpg
# ...
# Saved stylized image to: outputs/monet_stylev2\f6e822d131.jpg
# Saved stylized image to: outputs/monet_stylev2\f6e8f07d9d.jpg
# Saved stylized image to: outputs/monet_stylev2\f6efddda9c.jpg
# Saved stylized image to: outputs/monet_stylev2\f706c0860d.jpg
# Saved stylized image to: outputs/monet_stylev2\f70871846a.jpg
# Saved stylized image to: outputs/monet_stylev2\f71cc4d572.jpg
# Saved stylized image to: outputs/monet_stylev2\f721bb7f6d.jpg
# Saved stylized image to: outputs/monet_stylev2\f743f3bf62.jpg
# Saved stylized image to: outputs/monet_stylev2\f74cdcd632.jpg
# Saved stylized image to: outputs/monet_stylev2\f7531c3b99.jpg
# Saved stylized image to: outputs/monet_stylev2\f75a997bb8.jpg
# Saved stylized image to: outputs/monet_stylev2\f76e1ec9a3.jpg
# Saved stylized image to: outputs/monet_stylev2\f771e1e1b0.jpg
# Saved stylized image to: outputs/monet_stylev2\f77377bd03.jpg
# Saved stylized image to: outputs/monet_stylev2\f77505c83f.jpg
# Saved stylized image to: outputs/monet_stylev2\f77c59acb3.jpg
# Saved stylized image to: outputs/monet_stylev2\f77e3cb703.jpg
# Saved stylized image to: outputs/monet_stylev2\f77f395731.jpg
# Saved stylized image to: outputs/monet_stylev2\f790a14012.jpg
# Saved stylized image to: outputs/monet_stylev2\f79d9de05d.jpg
# Saved stylized image to: outputs/monet_stylev2\f7a011547d.jpg
# Saved stylized image to: outputs/monet_stylev2\f7a821c3c8.jpg
# Saved stylized image to: outputs/monet_stylev2\f7ae6e1d31.jpg
# Saved stylized image to: outputs/monet_stylev2\f7c4d8033d.jpg
# Saved stylized image to: outputs/monet_stylev2\f7c78a4eef.jpg
# Saved stylized image to: outputs/monet_stylev2\f7d0dba843.jpg
# Saved stylized image to: outputs/monet_stylev2\f7d0f59566.jpg
# Saved stylized image to: outputs/monet_stylev2\f7d17e77d6.jpg
# Saved stylized image to: outputs/monet_stylev2\f7dbdb551f.jpg
# Saved stylized image to: outputs/monet_stylev2\f7dc666b50.jpg
# Saved stylized image to: outputs/monet_stylev2\f7eb84fdb7.jpg
# Saved stylized image to: outputs/monet_stylev2\f7ee2469f6.jpg
# Saved stylized image to: outputs/monet_stylev2\f7f1d58022.jpg
# Saved stylized image to: outputs/monet_stylev2\f807c72b5d.jpg
# Saved stylized image to: outputs/monet_stylev2\f819274637.jpg
# Saved stylized image to: outputs/monet_stylev2\f81b1cc834.jpg
# Saved stylized image to: outputs/monet_stylev2\f82e8c30ac.jpg
# Saved stylized image to: outputs/monet_stylev2\f82fc48ba4.jpg
# Saved stylized image to: outputs/monet_stylev2\f8350e28db.jpg
# Saved stylized image to: outputs/monet_stylev2\f8363ba521.jpg
# Saved stylized image to: outputs/monet_stylev2\f83b161ca3.jpg
# Saved stylized image to: outputs/monet_stylev2\f83e5b4295.jpg
# Saved stylized image to: outputs/monet_stylev2\f843be17f5.jpg
# Saved stylized image to: outputs/monet_stylev2\f84566ed02.jpg
# Saved stylized image to: outputs/monet_stylev2\f84d77a2a6.jpg
# Saved stylized image to: outputs/monet_stylev2\f85694dfe6.jpg
# Saved stylized image to: outputs/monet_stylev2\f86b847b43.jpg
# Saved stylized image to: outputs/monet_stylev2\f876ba92ea.jpg
# Saved stylized image to: outputs/monet_stylev2\f87a1ab16d.jpg
# Saved stylized image to: outputs/monet_stylev2\f87deecaa2.jpg
# Saved stylized image to: outputs/monet_stylev2\f888dde817.jpg
# Saved stylized image to: outputs/monet_stylev2\f8905451b4.jpg
# Saved stylized image to: outputs/monet_stylev2\f895871068.jpg
# Saved stylized image to: outputs/monet_stylev2\f89bc86075.jpg
# Saved stylized image to: outputs/monet_stylev2\f8b6a915a9.jpg
# Saved stylized image to: outputs/monet_stylev2\f8b73f1a33.jpg
# Saved stylized image to: outputs/monet_stylev2\f8c19eaee6.jpg
# Saved stylized image to: outputs/monet_stylev2\f8c63eea5a.jpg
# Saved stylized image to: outputs/monet_stylev2\f8c8e456d7.jpg
# Saved stylized image to: outputs/monet_stylev2\f8ca80aebb.jpg
# Saved stylized image to: outputs/monet_stylev2\f8e10ef432.jpg
# Saved stylized image to: outputs/monet_stylev2\f8e488ce75.jpg
# Saved stylized image to: outputs/monet_stylev2\f8e6d9f481.jpg
# Saved stylized image to: outputs/monet_stylev2\f8f04744fd.jpg
# Saved stylized image to: outputs/monet_stylev2\f8f98ae176.jpg
# Saved stylized image to: outputs/monet_stylev2\f8fac4e7ff.jpg
# Saved stylized image to: outputs/monet_stylev2\f8ffd3ed06.jpg
# Saved stylized image to: outputs/monet_stylev2\f901dfad23.jpg
# Saved stylized image to: outputs/monet_stylev2\f904d3484c.jpg
# Saved stylized image to: outputs/monet_stylev2\f9080ec43b.jpg
# Saved stylized image to: outputs/monet_stylev2\f90edb8380.jpg
# Saved stylized image to: outputs/monet_stylev2\f90ee2b0db.jpg
# Saved stylized image to: outputs/monet_stylev2\f9151bda3c.jpg
# Saved stylized image to: outputs/monet_stylev2\f917b1c32a.jpg
# Saved stylized image to: outputs/monet_stylev2\f91c3d1f53.jpg
# Saved stylized image to: outputs/monet_stylev2\f91eb42b36.jpg
# Saved stylized image to: outputs/monet_stylev2\f930392388.jpg
# Saved stylized image to: outputs/monet_stylev2\f942443b5d.jpg
# Saved stylized image to: outputs/monet_stylev2\f954a8be77.jpg
# Saved stylized image to: outputs/monet_stylev2\f969505f84.jpg
# Saved stylized image to: outputs/monet_stylev2\f96a50841d.jpg
# Saved stylized image to: outputs/monet_stylev2\f97072faf8.jpg
# Saved stylized image to: outputs/monet_stylev2\f975a1e01e.jpg
# Saved stylized image to: outputs/monet_stylev2\f982a98853.jpg
# Saved stylized image to: outputs/monet_stylev2\f9843ad01b.jpg
# Saved stylized image to: outputs/monet_stylev2\f98627c542.jpg
# Saved stylized image to: outputs/monet_stylev2\f9867ce748.jpg
# Saved stylized image to: outputs/monet_stylev2\f9989c2bd5.jpg
# Saved stylized image to: outputs/monet_stylev2\f99a7a3267.jpg
# Saved stylized image to: outputs/monet_stylev2\f99f52c7f5.jpg
# Saved stylized image to: outputs/monet_stylev2\f99fe506ed.jpg
# Saved stylized image to: outputs/monet_stylev2\f9a20c7988.jpg
# Saved stylized image to: outputs/monet_stylev2\f9b4495f70.jpg
# Saved stylized image to: outputs/monet_stylev2\f9b4d017a3.jpg
# Saved stylized image to: outputs/monet_stylev2\f9ba7b025e.jpg
# Saved stylized image to: outputs/monet_stylev2\f9c9afcd78.jpg
# Saved stylized image to: outputs/monet_stylev2\f9cd461b5e.jpg
# Saved stylized image to: outputs/monet_stylev2\f9cf6e7e27.jpg
# Saved stylized image to: outputs/monet_stylev2\f9e8571801.jpg
# Saved stylized image to: outputs/monet_stylev2\f9f59d905c.jpg
# Saved stylized image to: outputs/monet_stylev2\f9f6bc6871.jpg
# Saved stylized image to: outputs/monet_stylev2\fa0fde7844.jpg
# Saved stylized image to: outputs/monet_stylev2\fa24240abc.jpg
# Saved stylized image to: outputs/monet_stylev2\fa307775e7.jpg
# Saved stylized image to: outputs/monet_stylev2\fa3aba5483.jpg
# Saved stylized image to: outputs/monet_stylev2\fa423fe5a3.jpg
# Saved stylized image to: outputs/monet_stylev2\fa428459e2.jpg
# Saved stylized image to: outputs/monet_stylev2\fa4326ff01.jpg
# Saved stylized image to: outputs/monet_stylev2\fa47656f02.jpg
# Saved stylized image to: outputs/monet_stylev2\fa48b1ceb5.jpg
# Saved stylized image to: outputs/monet_stylev2\fa60f9a0c9.jpg
# Saved stylized image to: outputs/monet_stylev2\fa63566e6e.jpg
# Saved stylized image to: outputs/monet_stylev2\fa728d214f.jpg
# Saved stylized image to: outputs/monet_stylev2\fa751def39.jpg
# Saved stylized image to: outputs/monet_stylev2\fa9a74e9a4.jpg
# Saved stylized image to: outputs/monet_stylev2\fa9a768c9b.jpg
# Saved stylized image to: outputs/monet_stylev2\faa4f82b52.jpg
# Saved stylized image to: outputs/monet_stylev2\faaab4fb19.jpg
# Saved stylized image to: outputs/monet_stylev2\fac89a2440.jpg
# Saved stylized image to: outputs/monet_stylev2\facc9d2df2.jpg
# Saved stylized image to: outputs/monet_stylev2\fad67f0f19.jpg
# Saved stylized image to: outputs/monet_stylev2\fb1779d922.jpg
# Saved stylized image to: outputs/monet_stylev2\fb24316c57.jpg
# Saved stylized image to: outputs/monet_stylev2\fb2a6a49d7.jpg
# Saved stylized image to: outputs/monet_stylev2\fb362a6660.jpg
# Saved stylized image to: outputs/monet_stylev2\fb3676a875.jpg
# Saved stylized image to: outputs/monet_stylev2\fb546829cb.jpg
# Saved stylized image to: outputs/monet_stylev2\fb562cd56b.jpg
# Saved stylized image to: outputs/monet_stylev2\fb73e20575.jpg
# Saved stylized image to: outputs/monet_stylev2\fb755692ce.jpg
# Saved stylized image to: outputs/monet_stylev2\fb85264917.jpg
# Saved stylized image to: outputs/monet_stylev2\fb8fb9b7c8.jpg
# Saved stylized image to: outputs/monet_stylev2\fb97febc5f.jpg
# Saved stylized image to: outputs/monet_stylev2\fb9c5403b8.jpg
# Saved stylized image to: outputs/monet_stylev2\fbaa1647e7.jpg
# Saved stylized image to: outputs/monet_stylev2\fbb5f72776.jpg
# Saved stylized image to: outputs/monet_stylev2\fbb8e36b1c.jpg
# Saved stylized image to: outputs/monet_stylev2\fbb8e5f081.jpg
# Saved stylized image to: outputs/monet_stylev2\fbc1c4e45b.jpg
# Saved stylized image to: outputs/monet_stylev2\fbc34e93dc.jpg
# Saved stylized image to: outputs/monet_stylev2\fbc3754be3.jpg
# Saved stylized image to: outputs/monet_stylev2\fbc70f973a.jpg
# Saved stylized image to: outputs/monet_stylev2\fbdaf94ace.jpg
# Saved stylized image to: outputs/monet_stylev2\fbf3ab42e9.jpg
# Saved stylized image to: outputs/monet_stylev2\fc02616c06.jpg
# Saved stylized image to: outputs/monet_stylev2\fc043d38eb.jpg
# Saved stylized image to: outputs/monet_stylev2\fc04ed2d42.jpg
# Saved stylized image to: outputs/monet_stylev2\fc075619e7.jpg
# Saved stylized image to: outputs/monet_stylev2\fc16c59788.jpg
# Saved stylized image to: outputs/monet_stylev2\fc30e458d6.jpg
# Saved stylized image to: outputs/monet_stylev2\fc458d4ee1.jpg
# Saved stylized image to: outputs/monet_stylev2\fc49fb17f3.jpg
# Saved stylized image to: outputs/monet_stylev2\fc51c26e2d.jpg
# Saved stylized image to: outputs/monet_stylev2\fc59b308a8.jpg
# Saved stylized image to: outputs/monet_stylev2\fc5feebdc8.jpg
# Saved stylized image to: outputs/monet_stylev2\fc622b5577.jpg
# Saved stylized image to: outputs/monet_stylev2\fc64e9fe13.jpg
# Saved stylized image to: outputs/monet_stylev2\fc6d47c7b0.jpg
# Saved stylized image to: outputs/monet_stylev2\fc9d809645.jpg
# Saved stylized image to: outputs/monet_stylev2\fcaeb2fb17.jpg
# Saved stylized image to: outputs/monet_stylev2\fcc0dc41b3.jpg
# Saved stylized image to: outputs/monet_stylev2\fcc59cb31d.jpg
# Saved stylized image to: outputs/monet_stylev2\fcd35ead6e.jpg
# Saved stylized image to: outputs/monet_stylev2\fcd5eaceb7.jpg
# Saved stylized image to: outputs/monet_stylev2\fcdd5b1e31.jpg
# Saved stylized image to: outputs/monet_stylev2\fce074b92c.jpg
# Saved stylized image to: outputs/monet_stylev2\fd0071794a.jpg
# Saved stylized image to: outputs/monet_stylev2\fd06d4e7e3.jpg
# Saved stylized image to: outputs/monet_stylev2\fd0a02921a.jpg
# Saved stylized image to: outputs/monet_stylev2\fd15f29d57.jpg
# Saved stylized image to: outputs/monet_stylev2\fd1f9293ca.jpg
# Saved stylized image to: outputs/monet_stylev2\fd20b4c41a.jpg
# Saved stylized image to: outputs/monet_stylev2\fd457c68d9.jpg
# Saved stylized image to: outputs/monet_stylev2\fd48eb1f90.jpg
# Saved stylized image to: outputs/monet_stylev2\fd49936788.jpg
# Saved stylized image to: outputs/monet_stylev2\fd4debe229.jpg
# Saved stylized image to: outputs/monet_stylev2\fd541f5f93.jpg
# Saved stylized image to: outputs/monet_stylev2\fd5ce86649.jpg
# Saved stylized image to: outputs/monet_stylev2\fd619e77af.jpg
# Saved stylized image to: outputs/monet_stylev2\fd6b68436e.jpg
# Saved stylized image to: outputs/monet_stylev2\fd6c9bcbfa.jpg
# Saved stylized image to: outputs/monet_stylev2\fd7d170a69.jpg
# Saved stylized image to: outputs/monet_stylev2\fd85d15361.jpg
# Saved stylized image to: outputs/monet_stylev2\fd8c99d93b.jpg
# Saved stylized image to: outputs/monet_stylev2\fd9767f897.jpg
# Saved stylized image to: outputs/monet_stylev2\fda550148e.jpg
# Saved stylized image to: outputs/monet_stylev2\fdad36c1e0.jpg
# Saved stylized image to: outputs/monet_stylev2\fdb01f9aba.jpg
# Saved stylized image to: outputs/monet_stylev2\fdb031e406.jpg
# Saved stylized image to: outputs/monet_stylev2\fdc2b3b936.jpg
# Saved stylized image to: outputs/monet_stylev2\fdc6c88003.jpg
# Saved stylized image to: outputs/monet_stylev2\fdce0c0d6d.jpg
# Saved stylized image to: outputs/monet_stylev2\fdd33c1145.jpg
# Saved stylized image to: outputs/monet_stylev2\fddc60bb99.jpg
# Saved stylized image to: outputs/monet_stylev2\fddcadfd3a.jpg
# Saved stylized image to: outputs/monet_stylev2\fde289be21.jpg
# Saved stylized image to: outputs/monet_stylev2\fde28fae2a.jpg
# Saved stylized image to: outputs/monet_stylev2\fde46f2be4.jpg
# Saved stylized image to: outputs/monet_stylev2\fdf013342c.jpg
# Saved stylized image to: outputs/monet_stylev2\fdf57fbe60.jpg
# Saved stylized image to: outputs/monet_stylev2\fdf84c4887.jpg
# Saved stylized image to: outputs/monet_stylev2\fdfc86a000.jpg
# Saved stylized image to: outputs/monet_stylev2\fe00c3d087.jpg
# Saved stylized image to: outputs/monet_stylev2\fe0a4f0e5a.jpg
# Saved stylized image to: outputs/monet_stylev2\fe1561993e.jpg
# Saved stylized image to: outputs/monet_stylev2\fe1c9d9e5a.jpg
# Saved stylized image to: outputs/monet_stylev2\fe283d4ae3.jpg
# Saved stylized image to: outputs/monet_stylev2\fe381a7c17.jpg
# Saved stylized image to: outputs/monet_stylev2\fe3c9d0016.jpg
# Saved stylized image to: outputs/monet_stylev2\fe3de96780.jpg
# Saved stylized image to: outputs/monet_stylev2\fe3feb7d1b.jpg
# Saved stylized image to: outputs/monet_stylev2\fe40ac1d8b.jpg
# Saved stylized image to: outputs/monet_stylev2\fe4c4e4b6b.jpg
# Saved stylized image to: outputs/monet_stylev2\fe5dc7ef05.jpg
# Saved stylized image to: outputs/monet_stylev2\fe6152a619.jpg
# Saved stylized image to: outputs/monet_stylev2\fe65abaafd.jpg
# Saved stylized image to: outputs/monet_stylev2\fe702a794e.jpg
# Saved stylized image to: outputs/monet_stylev2\fe714c846e.jpg
# Saved stylized image to: outputs/monet_stylev2\fe7af9c427.jpg
# Saved stylized image to: outputs/monet_stylev2\fe9cc12ae1.jpg
# Saved stylized image to: outputs/monet_stylev2\fea227771f.jpg
# Saved stylized image to: outputs/monet_stylev2\fea42e4505.jpg
# Saved stylized image to: outputs/monet_stylev2\fea4d4f76c.jpg
# Saved stylized image to: outputs/monet_stylev2\fea5afe679.jpg
# Saved stylized image to: outputs/monet_stylev2\feb132e4c1.jpg
# Saved stylized image to: outputs/monet_stylev2\fee0c39907.jpg
# Saved stylized image to: outputs/monet_stylev2\fefb86c469.jpg
# Saved stylized image to: outputs/monet_stylev2\fefcd07a5e.jpg
# Saved stylized image to: outputs/monet_stylev2\ff03c98f0e.jpg
# Saved stylized image to: outputs/monet_stylev2\ff2152ac2a.jpg
# Saved stylized image to: outputs/monet_stylev2\ff258e79ce.jpg
# Saved stylized image to: outputs/monet_stylev2\ff2cb6658c.jpg
# Saved stylized image to: outputs/monet_stylev2\ff2f57429f.jpg
# Saved stylized image to: outputs/monet_stylev2\ff3867d938.jpg
# Saved stylized image to: outputs/monet_stylev2\ff46474c6d.jpg
# Saved stylized image to: outputs/monet_stylev2\ff48e8580b.jpg
# Saved stylized image to: outputs/monet_stylev2\ff58af0f3b.jpg
# Saved stylized image to: outputs/monet_stylev2\ff5c15ab50.jpg
# Saved stylized image to: outputs/monet_stylev2\ff6ed45562.jpg
# Saved stylized image to: outputs/monet_stylev2\ff757d7db3.jpg
# Saved stylized image to: outputs/monet_stylev2\ff769c35c9.jpg
# Saved stylized image to: outputs/monet_stylev2\ff7d83bc1d.jpg
# Saved stylized image to: outputs/monet_stylev2\ff853f993b.jpg
# Saved stylized image to: outputs/monet_stylev2\ff9ca0e1bb.jpg
# Saved stylized image to: outputs/monet_stylev2\ff9e94857b.jpg
# Saved stylized image to: outputs/monet_stylev2\ffa1ee4875.jpg
# Saved stylized image to: outputs/monet_stylev2\ffa5d376be.jpg
# Saved stylized image to: outputs/monet_stylev2\ffbbb24b43.jpg
# Saved stylized image to: outputs/monet_stylev2\ffbdd43bfb.jpg
# Saved stylized image to: outputs/monet_stylev2\ffc5b52a77.jpg
# Saved stylized image to: outputs/monet_stylev2\ffcc20463a.jpg
# Saved stylized image to: outputs/monet_stylev2\ffcdd249dd.jpg
# Saved stylized image to: outputs/monet_stylev2\ffcf64f150.jpg
# Saved stylized image to: outputs/monet_stylev2\ffd71fce61.jpg
# Saved stylized image to: outputs/monet_stylev2\ffe1af8ca0.jpg
# Saved stylized image to: outputs/monet_stylev2\fff5c33050.jpg
# Saved stylized image to: outputs/monet_stylev2\fffaaaae65.jpg
# Saved stylized image to: outputs/monet_stylev2\fffc0836d7.jpg

# %%
from torch.utils.data import Dataset
from PIL import Image
import os

class FlatFolderDataset(Dataset):
    def __init__(self, folder, transform=None):
        self.files = sorted([
            os.path.join(folder, f) for f in os.listdir(folder)
            if f.lower().endswith(('.jpg', '.jpeg', '.png'))
        ])
        self.transform = transform
    
    def __len__(self):
        return len(self.files)
    
    def __getitem__(self, idx):
        img = Image.open(self.files[idx]).convert('RGB')
        if self.transform:
            img = self.transform(img)
        return img, 0  # dummy label

# %%
import torch
from torch.utils.data import DataLoader
from torchmetrics.image.fid import FrechetInceptionDistance
import torchvision.transforms as T

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

transform = T.Compose([
    T.Resize((256, 256)),  # match InceptionNet input
    T.PILToTensor()
])

real_dataset = FlatFolderDataset("datasets/real_imagesv2/photo_jpg", transform)
fake_dataset = FlatFolderDataset("outputs/monet_stylev2", transform)

real_loader = DataLoader(real_dataset, batch_size=16, shuffle=False, num_workers=0)
fake_loader = DataLoader(fake_dataset, batch_size=16, shuffle=False, num_workers=0)

fid = FrechetInceptionDistance(feature=2048).to(device)

# Feed real images
for batch, _ in real_loader:
    fid.update(batch.to(device), real=True)

# Feed fake images
for batch, _ in fake_loader:
    fid.update(batch.to(device), real=False)

# Compute FID score
fid_score = fid.compute().item()
print(f"FID Score: {fid_score:.4f}")
# Out:
# FID Score: 46.7764
